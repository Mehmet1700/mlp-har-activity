# %% [markdown]
# # 📊 Data Understanding
# Dieses Notebook dient der ersten Analyse des Human Activity Recognition Datensatzes
# Wir prüfen die Datenstruktur, Verteilungen, Zielvariable und potenzielle Probleme wie fehlende Werte oder Ungleichverteilung der Klassen.

# %%
# Librarie imports for data analysis and visualization

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import optparse

# Datenpfad
data_path = "./data/"

# %%
# Daten einlesen
import os
import pandas as pd

# Automatisch relativer Pfad von notebooks/ zu data/
data_path = os.path.join("..", "data") + "/"

# Optional: absolut anzeigen
print("Current working directory:", os.getcwd())
print("Data path:", data_path)

# CSVs einlesen
train_df = pd.read_csv(data_path + "train.csv")
test_df = pd.read_csv(data_path + "test.csv")
# Out:
# Current working directory: /pfs/data6/home/ds/ds_ds/ds_wi22254/mlp-har-activity/notebooks
# Data path: ../data/

# %%
#Grundlegende Datenanalyse

print ("Train shape:", train_df.shape)
print ("Test shape:", test_df.shape)
train_df.info
train_df.head()

train_df.describe()
# Out:
# Train shape: (7352, 563)
# Test shape: (2947, 563)
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %%
# Statistische Übersicht und Korrelation
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# ...
